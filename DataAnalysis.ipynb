# %% [markdown]
# The content of this file is for now experiments on the data that were used to produce the cleaned CVE data. Therefore it should be deleted eventually, for now i let it here for understanding of what i did and future referencement.
# If you want to generate the uncleaned then cleaned cve_data_cleaned, simply run the enrichissement_CVE file.
# if you want to generate only the cleaned one from the uncleaned one, run the subpart at the end of the enrichissement_CVE file

# %%
import pandas as pd

df = pd.read_csv("data/cve_data.csv")

# %%
print(df.head())
# Out:
#                                          alert_title          cve_id  \
# 0  Vulnérabilité dans Cisco Catalyst SD-WAN (05 j...  CVE-2026-20245
# 1  Multiples vulnérabilités dans les produits Mic...  CVE-2026-42507
# 2  Multiples vulnérabilités dans les produits Mic...  CVE-2026-42504
# 3  Multiples vulnérabilités dans Spring Micromete...  CVE-2026-40984
# 4  Multiples vulnérabilités dans Spring Micromete...  CVE-2026-40983
#
#                                          description      cvss_score  \
# 0  A vulnerability in the CLI of Cisco Catalyst S...             7.8
# 1  When returning errors, functions in the net/te...  Non disponible
# 2  Decoding a maliciously-crafted MIME header con...  Non disponible
# 3  In Micrometer, it is possible for a user to pr...             7.5
# 4  In Micrometer, it is possible for a user to pr...             7.5
#
#               cwe                                           cwe_desc  \
# 0         CWE-116            Improper Encoding or Escaping of Output
# 1  Non disponible  CWE-532: Insertion of Sensitive Information in...
# 2  Non disponible        CWE-407: Inefficient Algorithmic Complexity
# 3         CWE-400         CWE-400: Uncontrolled Resource Consumption
# 4         CWE-400         CWE-400: Uncontrolled Resource Consumption
#
#                                             affected  epss_score
# 0  [{"vendor": "Cisco", "product": "Cisco Catalys...     0.00356
# 1  [{"vendor": "Go standard library", "product": ...     0.00038
# 2  [{"vendor": "Go standard library", "product": ...     0.00055
# 3  [{"vendor": "Spring", "product": "Micrometer",...     0.00422
# 4  [{"vendor": "Spring", "product": "Micrometer",...     0.00040

# %%
print(df['affected'][0])
# Out:
# [{"vendor": "Cisco", "product": "Cisco Catalyst SD-WAN Manager", "versions": [{"version": "20.1.12", "status": "affected"}, {"version": "19.2.1", "status": "affected"}, {"version": "18.4.4", "status": "affected"}, {"version": "18.4.5", "status": "affected"}, {"version": "20.1.1.1", "status": "affected"}, {"version": "20.1.1", "status": "affected"}, {"version": "19.3.0", "status": "affected"}, {"version": "19.2.2", "status": "affected"}, {"version": "19.2.099", "status": "affected"}, {"version": "18.3.6", "status": "affected"}, {"version": "18.3.7", "status": "affected"}, {"version": "19.2.0", "status": "affected"}, {"version": "18.3.8", "status": "affected"}, {"version": "19.0.0", "status": "affected"}, {"version": "19.1.0", "status": "affected"}, {"version": "18.4.302", "status": "affected"}, {"version": "18.4.303", "status": "affected"}, {"version": "19.2.097", "status": "affected"}, {"version": "19.2.098", "status": "affected"}, {"version": "17.2.10", "status": "affected"}, {"version": "18.3.6.1", "status": "affected"}, {"version": "19.0.1a", "status": "affected"}, {"version": "18.2.0", "status": "affected"}, {"version": "18.4.3", "status": "affected"}, {"version": "18.4.1", "status": "affected"}, {"version": "17.2.8", "status": "affected"}, {"version": "18.3.3.1", "status": "affected"}, {"version": "18.4.0", "status": "affected"}, {"version": "18.3.1", "status": "affected"}, {"version": "17.2.6", "status": "affected"}, {"version": "17.2.9", "status": "affected"}, {"version": "18.3.4", "status": "affected"}, {"version": "17.2.5", "status": "affected"}, {"version": "18.3.1.1", "status": "affected"}, {"version": "18.3.5", "status": "affected"}, {"version": "18.4.0.1", "status": "affected"}, {"version": "18.3.3", "status": "affected"}, {"version": "17.2.7", "status": "affected"}, {"version": "17.2.4", "status": "affected"}, {"version": "18.3.0", "status": "affected"}, {"version": "19.2.3", "status": "affected"}, {"version": "18.4.501_ES", "status": "affected"}, {"version": "20.3.1", "status": "affected"}, {"version": "20.1.2", "status": "affected"}, {"version": "19.2.929", "status": "affected"}, {"version": "19.2.31", "status": "affected"}, {"version": "20.3.2", "status": "affected"}, {"version": "19.2.32", "status": "affected"}, {"version": "20.3.2_925", "status": "affected"}, {"version": "20.3.2.1", "status": "affected"}, {"version": "20.3.2.1_927", "status": "affected"}, {"version": "18.4.6", "status": "affected"}, {"version": "20.1.2_937", "status": "affected"}, {"version": "20.4.1", "status": "affected"}, {"version": "20.3.2_928", "status": "affected"}, {"version": "20.3.2_929", "status": "affected"}, {"version": "20.4.1.0.1", "status": "affected"}, {"version": "20.3.2.1_930", "status": "affected"}, {"version": "19.2.4", "status": "affected"}, {"version": "20.5.0.1.1", "status": "affected"}, {"version": "20.4.1.1", "status": "affected"}, {"version": "20.3.3", "status": "affected"}, {"version": "19.2.4.0.1", "status": "affected"}, {"version": "20.3.2_937", "status": "affected"}, {"version": "20.3.3.1", "status": "affected"}, {"version": "20.5.1", "status": "affected"}, {"version": "20.1.3", "status": "affected"}, {"version": "20.3.3.0.4", "status": "affected"}, {"version": "20.3.3.1.2", "status": "affected"}, {"version": "20.3.3.1.1", "status": "affected"}, {"version": "20.4.1.2", "status": "affected"}, {"version": "20.3.3.0.2", "status": "affected"}, {"version": "20.4.1.1.5", "status": "affected"}, {"version": "20.4.1.0.01", "status": "affected"}, {"version": "20.4.1.0.02", "status": "affected"}, {"version": "20.3.3.1.7", "status": "affected"}, {"version": "20.3.3.1.5", "status": "affected"}, {"version": "20.5.1.0.1", "status": "affected"}, {"version": "20.3.3.1.10", "status": "affected"}, {"version": "20.3.3.0.8", "status": "affected"}, {"version": "20.4.2", "status": "affected"}, {"version": "20.4.2.0.1", "status": "affected"}, {"version": "20.3.4", "status": "affected"}, {"version": "20.3.3.0.14", "status": "affected"} ...

# %%
print(type(df['affected']))
print(type(df['affected'][0]))
print(type(df['affected'][0][0]))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'str'>
# <class 'str'>

# %%
import ast
df["affected"] = df["affected"].apply(ast.literal_eval)

# %%
print(type(df['affected']))
print(type(df['affected'][0]))
print(type(df['affected'][0][0]))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'list'>
# <class 'dict'>

# %%
print(df["affected"][0][0]["versions"])
# Out:
# [{'version': '20.1.12', 'status': 'affected'}, {'version': '19.2.1', 'status': 'affected'}, {'version': '18.4.4', 'status': 'affected'}, {'version': '18.4.5', 'status': 'affected'}, {'version': '20.1.1.1', 'status': 'affected'}, {'version': '20.1.1', 'status': 'affected'}, {'version': '19.3.0', 'status': 'affected'}, {'version': '19.2.2', 'status': 'affected'}, {'version': '19.2.099', 'status': 'affected'}, {'version': '18.3.6', 'status': 'affected'}, {'version': '18.3.7', 'status': 'affected'}, {'version': '19.2.0', 'status': 'affected'}, {'version': '18.3.8', 'status': 'affected'}, {'version': '19.0.0', 'status': 'affected'}, {'version': '19.1.0', 'status': 'affected'}, {'version': '18.4.302', 'status': 'affected'}, {'version': '18.4.303', 'status': 'affected'}, {'version': '19.2.097', 'status': 'affected'}, {'version': '19.2.098', 'status': 'affected'}, {'version': '17.2.10', 'status': 'affected'}, {'version': '18.3.6.1', 'status': 'affected'}, {'version': '19.0.1a', 'status': 'affected'}, {'version': '18.2.0', 'status': 'affected'}, {'version': '18.4.3', 'status': 'affected'}, {'version': '18.4.1', 'status': 'affected'}, {'version': '17.2.8', 'status': 'affected'}, {'version': '18.3.3.1', 'status': 'affected'}, {'version': '18.4.0', 'status': 'affected'}, {'version': '18.3.1', 'status': 'affected'}, {'version': '17.2.6', 'status': 'affected'}, {'version': '17.2.9', 'status': 'affected'}, {'version': '18.3.4', 'status': 'affected'}, {'version': '17.2.5', 'status': 'affected'}, {'version': '18.3.1.1', 'status': 'affected'}, {'version': '18.3.5', 'status': 'affected'}, {'version': '18.4.0.1', 'status': 'affected'}, {'version': '18.3.3', 'status': 'affected'}, {'version': '17.2.7', 'status': 'affected'}, {'version': '17.2.4', 'status': 'affected'}, {'version': '18.3.0', 'status': 'affected'}, {'version': '19.2.3', 'status': 'affected'}, {'version': '18.4.501_ES', 'status': 'affected'}, {'version': '20.3.1', 'status': 'affected'}, {'version': '20.1.2', 'status': 'affected'}, {'version': '19.2.929', 'status': 'affected'}, {'version': '19.2.31', 'status': 'affected'}, {'version': '20.3.2', 'status': 'affected'}, {'version': '19.2.32', 'status': 'affected'}, {'version': '20.3.2_925', 'status': 'affected'}, {'version': '20.3.2.1', 'status': 'affected'}, {'version': '20.3.2.1_927', 'status': 'affected'}, {'version': '18.4.6', 'status': 'affected'}, {'version': '20.1.2_937', 'status': 'affected'}, {'version': '20.4.1', 'status': 'affected'}, {'version': '20.3.2_928', 'status': 'affected'}, {'version': '20.3.2_929', 'status': 'affected'}, {'version': '20.4.1.0.1', 'status': 'affected'}, {'version': '20.3.2.1_930', 'status': 'affected'}, {'version': '19.2.4', 'status': 'affected'}, {'version': '20.5.0.1.1', 'status': 'affected'}, {'version': '20.4.1.1', 'status': 'affected'}, {'version': '20.3.3', 'status': 'affected'}, {'version': '19.2.4.0.1', 'status': 'affected'}, {'version': '20.3.2_937', 'status': 'affected'}, {'version': '20.3.3.1', 'status': 'affected'}, {'version': '20.5.1', 'status': 'affected'}, {'version': '20.1.3', 'status': 'affected'}, {'version': '20.3.3.0.4', 'status': 'affected'}, {'version': '20.3.3.1.2', 'status': 'affected'}, {'version': '20.3.3.1.1', 'status': 'affected'}, {'version': '20.4.1.2', 'status': 'affected'}, {'version': '20.3.3.0.2', 'status': 'affected'}, {'version': '20.4.1.1.5', 'status': 'affected'}, {'version': '20.4.1.0.01', 'status': 'affected'}, {'version': '20.4.1.0.02', 'status': 'affected'}, {'version': '20.3.3.1.7', 'status': 'affected'}, {'version': '20.3.3.1.5', 'status': 'affected'}, {'version': '20.5.1.0.1', 'status': 'affected'}, {'version': '20.3.3.1.10', 'status': 'affected'}, {'version': '20.3.3.0.8', 'status': 'affected'}, {'version': '20.4.2', 'status': 'affected'}, {'version': '20.4.2.0.1', 'status': 'affected'}, {'version': '20.3.4', 'status': 'affected'}, {'version': '20.3.3.0.14', 'status': 'affected'}, {'version': '19.2.4.0.8', 'status': 'affected'}, {'version': '19.2.4.0.9',  ...

# %%
print(df["affected"][0][0].keys())
# Out:
# dict_keys(['vendor', 'product', 'versions', 'defaultStatus'])

# %%
df = df.explode("affected").reset_index(drop=True)

# %%
print(df["affected"])
print(type(df['affected']))
print(type(df['affected'][0]))
# Out:
# 0       {'vendor': 'Cisco', 'product': 'Cisco Catalyst...
# 1       {'vendor': 'Go standard library', 'product': '...
# 2       {'vendor': 'Go standard library', 'product': '...
# 3       {'vendor': 'Spring', 'product': 'Micrometer', ...
# 4       {'vendor': 'Spring', 'product': 'Micrometer', ...
#                               ...
# 3531    {'vendor': 'Spring', 'product': 'Spring Web Se...
# 3532    {'vendor': 'Spring', 'product': 'Spring Integr...
# 3533    {'vendor': 'Spring', 'product': 'Spring Web Se...
# 3534    {'vendor': 'Spring', 'product': 'Spring Web Se...
# 3535    {'vendor': 'Spring', 'product': 'Spring Web Se...
# Name: affected, Length: 3536, dtype: object
# <class 'pandas.core.series.Series'>
# <class 'dict'>

# %%
affected_normalized = pd.json_normalize(df["affected"])[["vendor", "product", "versions"]]

# %%
print(affected_normalized)
# Out:
#                    vendor                        product  \
# 0                   Cisco  Cisco Catalyst SD-WAN Manager
# 1     Go standard library                  net/textproto
# 2     Go standard library                           mime
# 3                  Spring                     Micrometer
# 4                  Spring                     Micrometer
# ...                   ...                            ...
# 3531               Spring            Spring Web Services
# 3532               Spring             Spring Integration
# 3533               Spring            Spring Web Services
# 3534               Spring            Spring Web Services
# 3535               Spring            Spring Web Services
#
#                                                versions
# 0     [{'version': '20.1.12', 'status': 'affected'},...
# 1     [{'version': '0', 'lessThan': '1.25.11', 'stat...
# 2     [{'version': '0', 'lessThan': '1.25.11', 'stat...
# 3     [{'status': 'affected', 'version': '1.16.0', '...
# 4     [{'status': 'affected', 'version': '1.16.0', '...
# ...                                                 ...
# 3531  [{'status': 'affected', 'version': '5.0.0', 'l...
# 3532  [{'status': 'affected', 'version': '7.0.0', 'l...
# 3533  [{'status': 'affected', 'version': '5.0.0', 'l...
# 3534  [{'status': 'affected', 'version': '5.0.0', 'l...
# 3535  [{'status': 'affected', 'version': '5.0.0', 'l...
#
# [3536 rows x 3 columns]

# %%
df = pd.concat([df.drop(columns="affected"), affected_normalized], axis=1)

# %%
print(df)
# Out:
#                                             alert_title          cve_id  \
# 0     Vulnérabilité dans Cisco Catalyst SD-WAN (05 j...  CVE-2026-20245
# 1     Multiples vulnérabilités dans les produits Mic...  CVE-2026-42507
# 2     Multiples vulnérabilités dans les produits Mic...  CVE-2026-42504
# 3     Multiples vulnérabilités dans Spring Micromete...  CVE-2026-40984
# 4     Multiples vulnérabilités dans Spring Micromete...  CVE-2026-40984
# ...                                                 ...             ...
# 3531  Multiples vulnérabilités dans les produits Spr...  CVE-2026-41000
# 3532  Multiples vulnérabilités dans les produits Spr...  CVE-2026-40987
# 3533  Multiples vulnérabilités dans les produits Spr...  CVE-2026-40997
# 3534  Multiples vulnérabilités dans les produits Spr...  CVE-2026-40999
# 3535  Multiples vulnérabilités dans les produits Spr...  CVE-2026-40998
#
#                                             description      cvss_score  \
# 0     A vulnerability in the CLI of Cisco Catalyst S...             7.8
# 1     When returning errors, functions in the net/te...  Non disponible
# 2     Decoding a maliciously-crafted MIME header con...  Non disponible
# 3     In Micrometer, it is possible for a user to pr...             7.5
# 4     In Micrometer, it is possible for a user to pr...             7.5
# ...                                                 ...             ...
# 3531  Wss4jSecurityInterceptor did not consistently ...             3.7
# 3532  A malicious or compromised FTP/SFTP/SMB server...             7.1
# 3533  Several Spring WS integration paths with Sprin...             5.3
# 3534  When WS-Addressing is used with non-anonymous ...             8.6
# 3535  Jaxp13XPathTemplate evaluated XPath expression...             8.2
#
#                  cwe                                           cwe_desc  \
# 0            CWE-116            Improper Encoding or Escaping of Output
# 1     Non disponible  CWE-532: Insertion of Sensitive Information in...
# 2     Non disponible        CWE-407: Inefficient Algorithmic Complexity
# 3            CWE-400         CWE-400: Uncontrolled Resource Consumption
# 4            CWE-400         CWE-400: Uncontrolled Resource Consumption
# ...              ...                                                ...
# 3531         CWE-294   CWE-294: Authentication Bypass by Capture-replay
# 3532          CWE-22  CWE-22: Improper Limitation of a Pathname to a...
# 3533         CWE-209  CWE-209: Generation of Error Message Containin...
# 3534         CWE-918        CWE-918: Server-Side Request Forgery (SSRF)
# 3535         CWE-611  CWE-611: Improper Restriction of XML External ...
#
#       epss_score               vendor                        product  \
# 0        0.00356                Cisco  Cisco Catalyst SD-WAN Manager
# 1        0.00038  Go standard library                  net/textproto
# 2        0.00055  Go standard library                           mime
# 3        0.00422               Spring                     Micrometer
# 4        0.00422               Spring                     Micrometer
# ...          ...                  ...                            ...
# 3531     0.00028               Spring            Spring Web Services
# 3532     0.00034               Spring             Spring Integration
# 3533     0.00042               Spring            Spring Web Services
# 3534     0.00032               Spring            Spring Web Services
# 3535     0.00036               Spring            Spring Web Services
#
#                                                versions
# 0     [{'version': '20.1.12', 'status': 'affected'},...
# 1     [{'version': '0', 'lessThan': '1.25.11', 'stat...
# 2     [{'version': '0', 'lessThan': '1.25.11', 'stat...
# 3     [{'status': 'affected', 'version': '1.16.0', '...
# 4     [{'status': 'affected', 'version': '1.16.0', '...
# ...                                                 ...
# 3531  [{'status': 'affected', 'version': '5.0.0', 'l...
# 3532  [{'status': 'affected', 'version': '7.0.0', 'l...
# 3533  [{'status': 'affected', 'version': '5.0.0', 'l...
# 3534  [{'status': 'affected', 'version': '5.0.0', 'l...
# 3535  [{'status': 'affected', 'version': '5.0.0', 'l...
#
# [3536 rows x 10 columns]

# %%
df["versions"] = df["versions"].apply(
    lambda lst: [d["version"] for d in lst] if isinstance(lst, list) else lst
)

# %%
df.to_csv("data/cve_data_cleaned.csv", index=False, encoding="utf-8")

# %%
#test

with open("data/cve_data_cleaned.csv", "w", encoding='utf-8') as f:
    f.write("a")

# %%
df2 = pd.read_csv("data/cve_data_cleaned.csv")

# %%
print(df2)
# Out:
#                                             alert_title          cve_id  \
# 0     Vulnérabilité dans Cisco Catalyst SD-WAN (05 j...  CVE-2026-20245
# 1     Multiples vulnérabilités dans les produits Mic...  CVE-2026-42507
# 2     Multiples vulnérabilités dans les produits Mic...  CVE-2026-42504
# 3     Multiples vulnérabilités dans Spring Micromete...  CVE-2026-40984
# 4     Multiples vulnérabilités dans Spring Micromete...  CVE-2026-40984
# ...                                                 ...             ...
# 3531  Multiples vulnérabilités dans les produits Spr...  CVE-2026-41000
# 3532  Multiples vulnérabilités dans les produits Spr...  CVE-2026-40987
# 3533  Multiples vulnérabilités dans les produits Spr...  CVE-2026-40997
# 3534  Multiples vulnérabilités dans les produits Spr...  CVE-2026-40999
# 3535  Multiples vulnérabilités dans les produits Spr...  CVE-2026-40998
#
#                                             description      cvss_score  \
# 0     A vulnerability in the CLI of Cisco Catalyst S...             7.8
# 1     When returning errors, functions in the net/te...  Non disponible
# 2     Decoding a maliciously-crafted MIME header con...  Non disponible
# 3     In Micrometer, it is possible for a user to pr...             7.5
# 4     In Micrometer, it is possible for a user to pr...             7.5
# ...                                                 ...             ...
# 3531  Wss4jSecurityInterceptor did not consistently ...             3.7
# 3532  A malicious or compromised FTP/SFTP/SMB server...             7.1
# 3533  Several Spring WS integration paths with Sprin...             5.3
# 3534  When WS-Addressing is used with non-anonymous ...             8.6
# 3535  Jaxp13XPathTemplate evaluated XPath expression...             8.2
#
#                  cwe                                           cwe_desc  \
# 0            CWE-116            Improper Encoding or Escaping of Output
# 1     Non disponible  CWE-532: Insertion of Sensitive Information in...
# 2     Non disponible        CWE-407: Inefficient Algorithmic Complexity
# 3            CWE-400         CWE-400: Uncontrolled Resource Consumption
# 4            CWE-400         CWE-400: Uncontrolled Resource Consumption
# ...              ...                                                ...
# 3531         CWE-294   CWE-294: Authentication Bypass by Capture-replay
# 3532          CWE-22  CWE-22: Improper Limitation of a Pathname to a...
# 3533         CWE-209  CWE-209: Generation of Error Message Containin...
# 3534         CWE-918        CWE-918: Server-Side Request Forgery (SSRF)
# 3535         CWE-611  CWE-611: Improper Restriction of XML External ...
#
#       epss_score               vendor                        product  \
# 0        0.00356                Cisco  Cisco Catalyst SD-WAN Manager
# 1        0.00038  Go standard library                  net/textproto
# 2        0.00055  Go standard library                           mime
# 3        0.00422               Spring                     Micrometer
# 4        0.00422               Spring                     Micrometer
# ...          ...                  ...                            ...
# 3531     0.00028               Spring            Spring Web Services
# 3532     0.00034               Spring             Spring Integration
# 3533     0.00042               Spring            Spring Web Services
# 3534     0.00032               Spring            Spring Web Services
# 3535     0.00036               Spring            Spring Web Services
#
#                                                versions
# 0     ['20.1.12', '19.2.1', '18.4.4', '18.4.5', '20....
# 1                                     ['0', '1.26.0-0']
# 2                                     ['0', '1.26.0-0']
# 3     ['1.16.0', '1.15.0', '1.14.0', '1.13.0', '1.9.0']
# 4              ['1.16.0', '1.15.0', '1.14.0', '1.13.0']
# ...                                                 ...
# 3531               ['5.0.0', '4.1.0', '4.0.0', '3.1.0']
# 3532      ['7.0.0', '6.5.0', '6.4.0', '6.3.0', '5.5.0']
# 3533               ['5.0.0', '4.1.0', '4.0.0', '3.1.0']
# 3534               ['5.0.0', '4.1.0', '4.0.0', '3.1.0']
# 3535               ['5.0.0', '4.1.0', '4.0.0', '3.1.0']
#
# [3536 rows x 10 columns]
